# %% [markdown]
# # Importing

# %%
import pandas as pd
import nltk
import spacy
from nltk import ngrams
from nltk.tokenize import word_tokenize 
from nltk.stem import SnowballStemmer
from sklearn.datasets import make_classification
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
import re
import pycld2 as cld2
from langdetect import detect
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/odelia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("WELFake_Dataset.csv")
df.drop(columns=["Unnamed: 0"], inplace=True)
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1                                                    NaN
# 2      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3      Bobby Jindal, raised Hindu, uses story of Chri...
# 4      SATAN 2: Russia unvelis an image of its terrif...
# ...                                                  ...
# 72129  Russians steal research on Trump in hack of U....
# 72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132  Trump tussle gives unpopular Mexican leader mu...
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# 1         Did they post their votes for Hillary already?      1
# 2       Now, most of the demonstrators gathered last ...      1
# 3      A dozen politically active pastors came here f...      0
# 4      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# ...                                                  ...    ...
# 72129  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 72130  You know, because in fantasyland Republicans n...      1
# 72131  Migrants Refuse To Leave Train At Refugee Camp...      0
# 72132  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...      1
#
# [72134 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72134 entries, 0 to 72133
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   71576 non-null  object
#  1   text    72095 non-null  object
#  2   label   72134 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df['label'].value_counts()
# Out:
# 1    37106
# 0    35028
# Name: label, dtype: int64

# %%
df[df['title'].isna() & df['text'].isna()]
# Out:
# Empty DataFrame
# Columns: [title, text, label]
# Index: []

# %%
df[df['title'].isna() | df['text'].isna()]
# Out:
#       title                                               text  label
# 1       NaN     Did they post their votes for Hillary already?      1
# 43      NaN  True. Hillary needs a distraction and what bet...      1
# 162     NaN  All eyes on Electoral delegates. The People kn...      1
# 185     NaN                                               Cool      1
# 269     NaN  A leading US senator: US Supporting War in Syr...      1
# ...     ...                                                ...    ...
# 71484   NaN  Another Arab supremacist masturbation fantasy....      1
# 71521   NaN  I'm sure they drastically changed accounting m...      1
# 71540   NaN  It's easy to imagine Obama or Kerry pissing hi...      1
# 71570   NaN  Ever since the powers to be assassinated JFK A...      1
# 71734   NaN             Hmm, free college, now that's an idea.      1
#
# [597 rows x 3 columns]

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      Bobby Jindal, raised Hindu, uses story of Chri...
# 3      SATAN 2: Russia unvelis an image of its terrif...
# 4      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 71532  Russians steal research on Trump in hack of U....
# 71533   WATCH: Giuliani Demands That Democrats Apolog...
# 71534  Migrants Refuse To Leave Train At Refugee Camp...
# 71535  Trump tussle gives unpopular Mexican leader mu...
# 71536  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# 1       Now, most of the demonstrators gathered last ...      1
# 2      A dozen politically active pastors came here f...      0
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 4      All we can say on this one is it s about time ...      1
# ...                                                  ...    ...
# 71532  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 71533  You know, because in fantasyland Republicans n...      1
# 71534  Migrants Refuse To Leave Train At Refugee Camp...      0
# 71535  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
# 71536  Goldman Sachs Endorses Hillary Clinton For Pre...      1
#
# [71537 rows x 3 columns]

# %% [markdown]
# # Text preprocessing
# ## With NLTK

# %% [markdown]
# ### Cleaning text

# %%
def clean(text):
    text = str(text).lower()
    text = re.sub(r'\s+', ' ', text)           # sequences of white spaces
    text = re.sub(r'[^\x00-\x7F]+',' ', text)  # Removing all the non ASCII characters
    text = re.sub(r'\s+',' ', text)            # Replacing multiple Spaces with Single Space
    text = re.sub(r'\.{2,}', ' ', text)        # Replacing Two or more dots with one
    text = re.sub(r'[^\x00-\x7F]+',' ', text)  # Removing all the non ASCII characters
    text = re.sub(r'\W+',' ', text)            # Replace everything non-alpahnumeric with a space
    return text.strip()

# %%
df['text_clean'] = df['text'].map(clean)
df['title_clean'] = df['title'].map(clean)

# %%
df["empty_cell_text"] = df['text_clean'].str.contains(r'^\s*$', na=False)
df["empty_cell_title"] = df['title_clean'].str.contains(r'^\s*$', na=False)

# %%
df
# Out:
#                                                 title  \
# 0   LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1   UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2   Bobby Jindal, raised Hindu, uses story of Chri...
# 3   SATAN 2: Russia unvelis an image of its terrif...
# 4   About Time! Christian Group Sues Amazon and SP...
# 5   DR BEN CARSON TARGETED BY THE IRS: “I never ha...
# 6   HOUSE INTEL CHAIR On Trump-Russia Fake Story: ...
# 7   Sports Bar Owner Bans NFL Games…Will Show Only...
# 8   Latest Pipeline Leak Underscores Dangers Of Da...
# 9    GOP Senator Just Smacked Down The Most Puncha...
# 10  May Brexit offer would hurt, cost EU citizens ...
# 11  Schumer calls on Trump to appoint official to ...
# 12  WATCH: HILARIOUS AD Calls Into Question Health...
# 13  No Change Expected for ESPN Political Agenda D...
# 14  Billionaire Odebrecht in Brazil scandal releas...
# 15  BRITISH WOMAN LOSES VIRGINITY To Asylum Seekin...
# 16  U.N. seeks humanitarian pause in Sanaa where s...
# 17  MAJOR LIBERAL RAG RELUCTANTLY PUBLISHES Articl...
# 18  Second judge says Clinton email setup may have...
# 19                 America gives Grand Piano to horse
# 20  Hillary’s crime family: End of days for the U.S.A
# 21   Sean Spicer Baffles Reporters, Claims Trump I...
# 22  UNHOLY ALLIANCE: Hillary Clinton’s Saudi Spons...
# 23   Even Trump’s Best Friend Joe Scarborough Can’...
# 24  BOOM! Danish Government Considers Seizing Migr...
# 25  Supreme Court Won’t Hear Appeal From Texas on ...
# 26  Islamic State driven out of last stronghold in...
# 27  Senators Propose Giving States Option to Keep ...
# 28      Do You Belong To An Extraterrestrial Lineage?
# 29  Zimbabwe's Mugabe appears in public for first ...
# 30  Credit Suisse Boss Faces Revolt From Bankers O...
# 31  THE ROBBING OF INNOCENCE: 12 Yr Old Students G...
# 32  Schaeuble to head German parliament, unblockin...
# 33  At U.S.-China summit, Trump presses Xi on trad...
# 34  Clinton extends lead over Trump to 7 points: R...
# 35  JOE BIDEN’S SHOCKING ANNOUNCEMENT: “What the h...
# 36  Comment une petite fille russe de 4 ans a appr...
# 37   Emboldened NRA Threatens New York Times: ‘We’...
# 38   Noam Chomsky GOES OFF On Donald Trump: ‘He’s ...
# 39  5 Ways The Media Responded With Butthurt To Do...
# 40  Iran, Russia and Turkey Agree to Enforce Syria...
# 41  BREAKING: OBAMA POISED To Exact Revenge On PUT...
# 42  Trump says Brexit to be 'a great thing', wants...
# 43  Sekulow: Expect ‘Whining Testimony’ from Comey...
# 44  Mayday on the Carolina Queen - The New York Times
# 45  Illinois House passes $5 billion tax package, ...
# 46         AT&T, Time Warner and the Death of Privacy
# 47  An Architect Who Built His Career on Resuscita...
# 48                          American dream, revisited
# 49  Fear of Iranian general left Iraqi Kurdish oil...
#
#                                                  text  label  \
# 0   No comment is expected from Barack Obama Membe...      1
# 1    Now, most of the demonstrators gathered last ...      1
# 2   A dozen politically active pastors came here f...      0
# 3   The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 
# 23  even trump s best friend joe scarborough can t...            False
# 24  boom danish government considers seizing migra...            False
# 25  supreme court won t hear appeal from texas on ...            False
# 26  islamic state driven out of last stronghold in...            False
# 27  senators propose giving states option to keep ...            False
# 28       do you belong to an extraterrestrial lineage            False
# 29  zimbabwe s mugabe appears in public for first ...            False
# 30  credit suisse boss faces revolt from bankers o...            False
# 31  the robbing of innocence 12 yr old students gi...            False
# 32  schaeuble to head german parliament unblocking...            False
# 33  at u s china summit trump presses xi on trade ...            False
# 34  clinton extends lead over trump to 7 points re...            False
# 35  joe biden s shocking announcement what the hel...            False
# 36  comment une petite fille russe de 4 ans a appr...            False
# 37  emboldened nra threatens new york times we re ...            False
# 38  noam chomsky goes off on donald trump he s a c...            False
# 39  5 ways the media responded with butthurt to do...            False
# 40  iran russia and turkey agree to enforce syria ...            False
# 41  breaking obama poised to exact revenge on puti...            False
# 42  trump says brexit to be a great thing wants qu...            False
# 43  sekulow expect whining testimony from comey he...            False
# 44    mayday on the carolina queen the new york times            False
# 45  illinois house passes 5 billion tax package sp...            False
# 46          at t time warner and the death of privacy            False
# 47  an architect who built his career on resuscita...            False
# 48                           american dream revisited            False
# 49  fear of iranian general left iraqi kurdish oil...            False
#
#     empty_cell_title
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# 6              False
# 7              False
# 8              False
# 9              False
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False
# 19             False
# 20             False
# 21             False
# 22             False
# 23             False
# 24             False
# 25             False
# 26             False
# 27             False
# 28             False
# 29             False
# 30             False
# 31             False
# 32             False
# 33             False
# 34             False
# 35             False
# 36             False
# 37             False
# 38             False
# 39             False
# 40             False
# 41             False
# 42             False
# 43             False
# 44             False
# 45             False
# 46             False
# 47             False
# 48             False
# 49             False

# %% [markdown]
# ### Removing empty cells

# %%
df.drop(df.loc[df["empty_cell_text" or "empty_cell_title"]].index, inplace=True)
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      Bobby Jindal, raised Hindu, uses story of Chri...
# 3      SATAN 2: Russia unvelis an image of its terrif...
# 4      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 71532  Russians steal research on Trump in hack of U....
# 71533   WATCH: Giuliani Demands That Democrats Apolog...
# 71534  Migrants Refuse To Leave Train At Refugee Camp...
# 71535  Trump tussle gives unpopular Mexican leader mu...
# 71536  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label  \
# 0      No comment is expected from Barack Obama Membe...      1
# 1       Now, most of the demonstrators gathered last ...      1
# 2      A dozen politically active pastors came here f...      0
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 4      All we can say on this one is it s about time ...      1
# ...                                                  ...    ...
# 71532  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 71533  You know, because in fantasyland Republicans n...      1
# 71534  Migrants Refuse To Leave Train At Refugee Camp...      0
# 71535  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
# 71536  Goldman Sachs Endorses Hillary Clinton For Pre...      1
#
#                                               text_clean  \
# 0      no comment is expected from barack obama membe...
# 1      now most of the demonstrators gathered last ni...
# 2      a dozen politically active pastors came here f...
# 3      the rs 28 sarmat missile dubbed satan 2 will r...
# 4      all we can say on this one is it s about time ...
# ...                                                  ...
# 71532  washington reuters hackers believed to be work...
# 71533  you know because in fantasyland republicans ne...
# 71534  migrants refuse to leave train at refugee camp...
# 71535  mexico city reuters donald trump s combative s...
# 71536  goldman sachs endorses hillary clinton for pre...
#
#                                              title_clean  empty_cell_text  \
# 0      law enforcement on high alert following threat...            False
# 1      unbelievable obama s attorney general says mos...            False
# 2      bobby jindal raised hindu uses story of christ...            False
# 3      satan 2 russia unvelis an image of its terrify...            False
# 4      about time christian group sues amazon and spl...            False
# ...                                                  ...              ...
# 71532  russians steal research on trump in hack of u ...            False
# 71533  watch giuliani demands that democrats apologiz...            False
# 71534  migrants refuse to leave train at refugee camp...            False
# 71535  trump tussle gives unpopular mexican leader mu...            False
# 71536  goldman sachs endorses hillary clinton for pre...            False
#
#        empty_cell_title
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 71532             False
# 71533             False
# 71534             False
# 71535             False
# 71536             False
#
# [70781 rows x 7 columns]

# %%
df.reset_index(drop=True, inplace=True)
df.drop(columns=["empty_cell_text", "empty_cell_title"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_43897/3805372135.py in <module>
#       1 df.reset_index(drop=True, inplace=True)
# ----> 2 df.drop(columns=["empty_cell_text", "empty_cell_title"], inplace=True)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['empty_cell_text' 'empty_cell_title'] not found in axis"

# %%
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      Bobby Jindal, raised Hindu, uses story of Chri...
# 3      SATAN 2: Russia unvelis an image of its terrif...
# 4      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 70776  Russians steal research on Trump in hack of U....
# 70777   WATCH: Giuliani Demands That Democrats Apolog...
# 70778  Migrants Refuse To Leave Train At Refugee Camp...
# 70779  Trump tussle gives unpopular Mexican leader mu...
# 70780  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label  \
# 0      No comment is expected from Barack Obama Membe...      1
# 1       Now, most of the demonstrators gathered last ...      1
# 2      A dozen politically active pastors came here f...      0
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 4      All we can say on this one is it s about time ...      1
# ...                                                  ...    ...
# 70776  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 70777  You know, because in fantasyland Republicans n...      1
# 70778  Migrants Refuse To Leave Train At Refugee Camp...      0
# 70779  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
# 70780  Goldman Sachs Endorses Hillary Clinton For Pre...      1
#
#                                               text_clean  \
# 0      no comment is expected from barack obama membe...
# 1      now most of the demonstrators gathered last ni...
# 2      a dozen politically active pastors came here f...
# 3      the rs 28 sarmat missile dubbed satan 2 will r...
# 4      all we can say on this one is it s about time ...
# ...                                                  ...
# 70776  washington reuters hackers believed to be work...
# 70777  you know because in fantasyland republicans ne...
# 70778  migrants refuse to leave train at refugee camp...
# 70779  mexico city reuters donald trump s combative s...
# 70780  goldman sachs endorses hillary clinton for pre...
#
#                                              title_clean
# 0      law enforcement on high alert following threat...
# 1      unbelievable obama s attorney general says mos...
# 2      bobby jindal raised hindu uses story of christ...
# 3      satan 2 russia unvelis an image of its terrify...
# 4      about time christian group sues amazon and spl...
# ...                                                  ...
# 70776  russians steal research on trump in hack of u ...
# 70777  watch giuliani demands that democrats apologiz...
# 70778  migrants refuse to leave train at refugee camp...
# 70779  trump tussle gives unpopular mexican leader mu...
# 70780  goldman sachs endorses hillary clinton for pre...
#
# [70781 rows x 5 columns]

# %%
df.to_csv("df_cleaned.csv")

# %% [markdown]
# ### Language detection

# %%
def detect_lang(text):
    _, _, _, detected_language = cld2.detect(text, returnVectors=True)
    return str(detected_language)

# %%
df['text_lang'] = df['text_clean'].map(detect_lang)
df['title_lang'] = df['title_clean'].map(detect_lang)

# %%
.as_type("string")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_43897/2205838850.py in <module>
# ----> 1 df.as_type("string")
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'as_type'

# %%
df.query("text_lang" == "ENGLISH",)
# Out:
#   File "/var/folders/nx/7crq4wx155z00jtfy6fbs9bw0000gn/T/ipykernel_43897/573983797.py", line 1
#     df.query("text_lang"=="ENGLISH", 'bool' = False)
#                                      ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %% [markdown]
# ### Tokenizing

# %%
tokenizer = nltk.data.load("tokenizers/punkt/english.pickle")
df['token_title'] = df.apply(lambda row: nltk.word_tokenize(row['title_clean']), axis=1)

# %%
df['token_text'] = df.apply(lambda row: nltk.word_tokenize(row['text_clean']), axis=1)

# %%
df

# %%
#pd.df.to_csv("df_token.csv")

# %% [markdown]
# ### Lemmatizing

# %%
nltk.download('omw-1.4')
lem = WordNetLemmatizer()
